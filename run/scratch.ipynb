# %%
import numpy as np
import matplotlib.pyplot as plt
from pyna.frequency_bands import get_frequency_bands, get_frequency_subbands, get_spectrum_subbands

# %%
n_frequency_bands = 24
n_subbands = 11
f = get_frequency_bands(n_frequency_bands)
f_sb = get_frequency_subbands(f, n_subbands)

# %%
# msap = np.linspace(1e-5, 10e-5, 24)
msap = np.ones(24)*1e-5
msap_sb = get_spectrum_subbands(msap, 11)

# %%
plt.figure(figsize=(20, 6))
plt.semilogx(f, msap, '.-'),
plt.semilogx(f_sb, msap_sb, '.-')

# %%
i = 0
sum(msap_sb[i*n_subbands:(i+1)*n_subbands])
# Out:
# np.float64(1e-05)
