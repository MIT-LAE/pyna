# %%
import numpy as np
from pyna.atmosphere import speed_of_sound, temperature_at_altitude

# %%
# Inputs
# Extract inputs
n_timestamps = 4

x = np.linspace(0, 10, n_timestamps)
y = np.linspace(0, 10, n_timestamps)
z = np.linspace(0, 10000, n_timestamps)
alpha = np.linspace(1, 10, n_timestamps) * np.pi/180
gamma = np.linspace(5, 10, n_timestamps) * np.pi/180
t_s = np.linspace(0, 100, n_timestamps)
c_0 = np.linspace(350, 350, n_timestamps)
T_0 = np.linspace(300., 300, n_timestamps)
observer_position = np.array([6500., 0, 1.2])
source_z_offset = 4.

_LAPSE_RATE_TROPOSPHERE = -0.0065
